# %% [markdown]
# <a href="https://colab.research.google.com/github/Santosdevbjj/processoRedundanciaArqAzure/blob/main/databricks_notebooks_bronze_promote_%3Ctabela%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "source": [
    "# Bronze Promotion Notebook\n",
    "Este notebook lê dados da camada RAW e promove para BRONZE aplicando limpeza básica."
   ]
  },
  {
   "cell_type": "code",
   "source": [
    "from pyspark.sql import SparkSession\n",
    "spark = SparkSession.builder.getOrCreate()\n",
    "\n",
    "raw_path = 'abfss://raw@stredundancia<seu-id>.dfs.core.windows.net/sql_onprem/SampleTable/'\n",
    "bronze_path = 'abfss://bronze@stredundancia<seu-id>.dfs.core.windows.net/sql_onprem/SampleTable/'\n",
    "\n",
    "df = spark.read.option('header', True).csv(raw_path)\n",
    "df_clean = df.dropna()\n",
    "df_clean.write.mode('overwrite').option('header', True).csv(bronze_path)"
   ]
  }
 ],
 "nbformat": 4
}
